# %%
# csv and numpy packages are imported

import csv as csv 
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
from pandas import * 
# %matplotlib inline

# %%
plt.figure(figsize=(15,15))
my_map = Basemap(lat_0=40.7128, lon_0=-74.0059,
    resolution = 'h', area_thresh = 1000.0,
    llcrnrlon=-74.252020, llcrnrlat=40.497798,
    urcrnrlon=-73.749981, urcrnrlat=40.918847)
my_map.drawcoastlines()
my_map.drawcountries()
my_map.drawrivers()
my_map.fillcontinents(color='coral',lake_color='aqua')
my_map.drawmapboundary(fill_color='aqua')
 
plt.show()

# %%
# my_map = Basemap(width=12000000,height=9000000, lat_0=40.7128, lon_0=-74.0059, projection = 'lcc',
#   resolution=None)
 
# my_map.bluemarble() 
# plt.show()

# %%
trip_data_file = open('../nyc_taxi_files/trip_data_1.csv', 'r')
trip_data = csv.reader(trip_data_file)
header_1 = trip_data.next()

data = []
for i in range(100000):
    data.append(trip_data.next())
#print trip_data.next()
#print trip_data.next()
trip_data_file.close()

# %%
tripdata_df = DataFrame(data=data, columns=header_1)
tripdata_df
# Out:
#                               medallion                      hack_license  \
# 0      89D227B655E5C82AECF13C3F540D4CF4  BA96DE419E711691B9445D6A6307C170
# 1      0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2      0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3      DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4      DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5      20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6      496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7      0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8      2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9      2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
# 10     E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# 11     E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# ...

# %%
test_file = open('../nyc_taxi_files/nyc_taxi_data.csv', 'r')
test_file_object = csv.reader(test_file)
header = test_file_object.next()

print(header)
# Out:
# ['vendor_id', 'pickup_datetime', 'dropoff_datetime', 'passenger_count', 'trip_distance', 'pickup_longitude', 'pickup_latitude', 'rate_code', 'store_and_fwd_flag', 'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount', 'surcharge', 'mta_tax', 'tip_amount', 'tolls_amount', 'total_amount']

# %%
test_file.close()

# %%
test_file = open('./nyc_taxi_data.csv', 'r')
test_file_object = csv.reader(test_file)
header = test_file_object.next()

row = test_file_object.next()
print ("Longitude of pickup point is %f" % float(row[5]))
print ("Latitude of pickup point is %f" % float(row[6]))

print ("Longitude of dropoff point is %f" % float(row[9]))
print ("Latitude of dropoff point is %f" % float(row[10])) 

test_file.close()
# Out:
# Longitude of pickup point is -73.994770
# Latitude of pickup point is 40.736828
# Longitude of dropoff point is -73.982227
# Latitude of dropoff point is 40.731790

# %%
test_file = open('../nyc_taxi_files/nyc_taxi_data.csv', 'r')
test_file_object = csv.reader(test_file)
header = test_file_object.next()

row = test_file_object.next()

pickup_lon = float(row[5])
pickup_lat = float(row[6])

dropoff_lon = float(row[9])
dropoff_lat = float(row[10])

test_file.close()

my_map = Basemap(projection='merc', lat_0=40.7128, lon_0=-74.0059,
    resolution = 'h', area_thresh = 0.001,
    llcrnrlon=-74.018629, llcrnrlat=40.704889,
    urcrnrlon=-73.905500, urcrnrlat=40.831201)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.drawrivers()
my_map.fillcontinents(color='coral',lake_color='aqua')
my_map.drawmapboundary(fill_color='aqua')
 
x1,y1 = my_map(pickup_lon, pickup_lat)
x2,y2 = my_map(dropoff_lon, dropoff_lat)

my_map.plot(x1, y1, 'bo', markersize=5)
my_map.plot(x2, y2, 'ro', markersize=5)

plt.show()

# %%
df = DataFrame({'Lat':[], 'Lon':[]})
df = df.append(DataFrame({'Lat':[1,2,3,4], 'Lon':[2,3,4,5]}), ignore_index = True)

df
# Out:
#    Lat  Lon
# 0    1    2
# 1    2    3
# 2    3    4
# 3    4    5

# %%
df = DataFrame({'Lat':[1,2,3,4], 'Lon':[2,3,4,5]})

for row in range (len(df)):
    print (df['Lat'][row], df['Lon'][row])
# Out:
# (1, 2)
# (2, 3)
# (3, 4)
# (4, 5)

# %%
df = DataFrame({'Lat':[], 'Lon':[]})
df = df.append(DataFrame({'Lat':[1,2,3,4], 'Lon':[2,3,4,5]}))

for row in range (len(df)):
    print (df['Lat'][row])
    print (df['Lon'][row])
# Out:
# 1.0
# 2.0
# 2.0
# 3.0
# 3.0
# 4.0
# 4.0
# 5.0

# %%
test_file = open('../nyc_taxi_files/nyc_taxi_data.csv', 'r')
test_file_object = csv.reader(test_file)
header = test_file_object.next()

plt.figure(figsize=(15,15))
my_map = Basemap(projection='merc', lat_0=40.7128, lon_0=-74.0059,
    resolution = 'h', area_thresh = 0.001,
    llcrnrlon=-74.018629, llcrnrlat=40.704889,
    urcrnrlon=-73.905500, urcrnrlat=40.831201)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.drawrivers()
my_map.fillcontinents(color='coral',lake_color='aqua')
my_map.drawmapboundary(fill_color='aqua')

pickup_df = DataFrame({'Lon':[], 'Lat':[]})
dropoff_df = DataFrame({'Lon':[], 'Lat':[]})


for i in range (5000):
    row = test_file_object.next()
    pickup_df = pickup_df.append(DataFrame({'Lon':[float(row[5])], 'Lat':[float(row[6])]}), ignore_index = True)
    dropoff_df = dropoff_df.append(DataFrame({'Lon':[float(row[9])], 'Lat':[float(row[10])]}), ignore_index = True)

test_file.close()

for row in range (len(pickup_df)):
    x1,y1 = my_map(pickup_df['Lon'][row], pickup_df['Lat'][row])
    x2,y2 = my_map(dropoff_df['Lon'][row], dropoff_df['Lat'][row])

    my_map.plot(x1, y1, 'bx', markersize=5)
    my_map.plot(x2, y2, 'ro', markersize=5)
    
plt.show()

# %%
import csv as csv 
from mpl_toolkits.basemap import Basemap
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import * 

test_file = open('../nyc_taxi_files/nyc_taxi_data.csv', 'r')
test_file_object = csv.reader(test_file)
header = test_file_object.next()

df = DataFrame({'Lon':[], 'Lat':[]})

for i in range (100000):
    row = test_file_object.next()
    try:
        df = df.append(DataFrame({'Lon':[float(row[5])], 'Lat':[float(row[6])]}), ignore_index = True)
        df = df.append(DataFrame({'Lon':[float(row[9])], 'Lat':[float(row[10])]}), ignore_index = True)
    
    except:
        continue

test_file.close()

pd.options.display.mpl_style = 'default' #Better Styling  
new_style = {'grid': False} #Remove grid  
matplotlib.rc('axes', **new_style)  
from matplotlib import rcParams  
rcParams['figure.figsize'] = (12.5, 12.5) #Size of figure  
rcParams['figure.dpi'] = 250

P=df.plot(kind='scatter', x='Lon', y='Lat',color='black',xlim=(-74.05,-73.85),ylim=(40.61, 40.91),s=.02,alpha=.6)

P.set_axis_bgcolor('grey') #Background Color

# %%
import csv as csv 
from mpl_toolkits.basemap import Basemap
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import * 

test_file = open('../nyc_taxi_files/nyc_taxi_data.csv', 'r')
test_file_object = csv.reader(test_file)
header = test_file_object.next()

df = DataFrame({'Lon':[], 'Lat':[]})

count = 0
for row in test_file_object:
    if count <= 100000:
        try:
            df = df.append(DataFrame({'Lon':[float(row[5])], 'Lat':[float(row[6])]}), ignore_index = True)
            df = df.append(DataFrame({'Lon':[float(row[9])], 'Lat':[float(row[10])]}), ignore_index = True)
            count += 1
    
        except:
            count += 1
            continue
    else:
        break

test_file.close()

pd.options.display.mpl_style = 'default' #Better Styling  
new_style = {'grid': False} #Remove grid  
matplotlib.rc('axes', **new_style)  
from matplotlib import rcParams  
rcParams['figure.figsize'] = (17.5, 17) #Size of figure  
rcParams['figure.dpi'] = 250

P=df.plot(kind='scatter', x='Lon', y='Lat',color='black',xlim=(-74.06,-73.77),ylim=(40.61, 40.91),s=.02,alpha=.6)

P.set_axis_bgcolor('white') #Background Color

# %%
import csv as csv 
from mpl_toolkits.basemap import Basemap
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import * 

#Inline Plotting for Ipython Notebook 
# %matplotlib inline 

test_file = open('./nyc_taxi_data.csv', 'r')
test_file_object = csv.reader(test_file)

row_count = sum(1 for row in test_file_object)

print row_count

test_file.close()
# Out:
# 165114362
